# %% [markdown]
# <a href="https://colab.research.google.com/github/Dedeepya0510/ITA0602--Machine-Learning/blob/main/Lab%20Activity/Exp_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
from sklearn.mixture import GaussianMixture

uploaded = files.upload()

df = pd.read_csv(next(iter(uploaded)))

print(df.head())

X = df.iloc[:, :-1]

gmm = GaussianMixture(n_components=2, random_state=42)

gmm.fit(X)

labels = gmm.predict(X)

print("\nCluster Labels")

print(labels)
