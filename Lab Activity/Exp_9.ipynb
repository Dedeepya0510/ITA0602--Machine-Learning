# %% [markdown]
# <a href="https://colab.research.google.com/github/Dedeepya0510/ITA0602--Machine-Learning/blob/main/Lab%20Activity/Exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

uploaded = files.upload()

df = pd.read_csv(next(iter(uploaded)))

print(df.head())

X = df[['StudyHours']]
y = df['PreviousMarks']

linear = LinearRegression()
linear.fit(X, y)

poly = PolynomialFeatures(degree=2)

X_poly = poly.fit_transform(X)

poly_model = LinearRegression()
poly_model.fit(X_poly, y)

plt.scatter(X, y)

plt.plot(X, linear.predict(X), label="Linear")

plt.plot(X, poly_model.predict(X_poly), label="Polynomial")

plt.legend()

plt.show()
